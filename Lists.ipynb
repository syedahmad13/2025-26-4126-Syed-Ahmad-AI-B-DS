# %% [markdown]
# <a href="https://colab.research.google.com/github/syedahmad13/2025-26-4126-Syed-Ahmad-AI-B-DS/blob/main/Lists.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=[5,10,15,20]
a.append(25)
a.extend([25,30])
print("Multiples of 5:",a)
# Out:
# Multiples of 5: [5, 10, 15, 20, 25, 25, 30]
