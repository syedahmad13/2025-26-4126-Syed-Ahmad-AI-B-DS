# %% [markdown]
# <a href="https://colab.research.google.com/github/syedahmad13/2025-26-4126-Syed-Ahmad-AI-B-DS/blob/main/datasets.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
url=
df=pd.read_csv(url)
print(df.head)
df.to_csv(r"d:\iris_dataset.csv",index=false)
print("Dataset saved successfully to local drive!")
# Out:
#   File "/tmp/ipython-input-2816115135.py", line 2
#     url=
#         ^
# SyntaxError: invalid syntax
