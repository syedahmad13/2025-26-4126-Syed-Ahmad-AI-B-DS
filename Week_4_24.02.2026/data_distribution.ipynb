# %% [markdown]
# <a href="https://colab.research.google.com/github/syedahmad13/2025-26-4126-Syed-Ahmad-AI-B-DS/blob/main/Week_4_24.02.2026/data_distribution.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Data Distribution
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
normal_data=np.random.normal(loc=70,scale=5,size=1000)
right_skewed=np.random.exponential(scale=2,size=1000)
left_skewed=-np.random.exponential(scale=2,size=1000)
plt.hist(normal_data,bins=30)
plt.title("Normal Distribution")
plt.show()
plt.hist(right_skewed,bins=30)
plt.title("Right Skewed Distribution")
plt.show()
plt.hist(left_skewed,bins=30)
plt.title("Left Skewed Distribution")
plt.show()
print("Normal Data Mean:",np.mean(normal_data))
print("Normal Data Median:",np.median(normal_data))
print("Right Skewed Mean:",np.mean(right_skewed))
print("Right Skewed Median:",np.median(right_skewed))
print("Left Skewed Mean:",np.mean(left_skewed))
print("Left Skewed Median:",np.median(left_skewed))
# Out:
# Normal Data Mean: 69.82597519833139
# Normal Data Median: 69.65446553828109
# Right Skewed Mean: 1.870382748303184
# Right Skewed Median: 1.4018953953072817
# Left Skewed Mean: -2.014600120498389
# Left Skewed Median: -1.3403894014521316

# %%
#uniform distribution
import numpy as np
import matplotlib.pyplot as plt

# Generate Data
uniform_data = np.random.uniform(low=50, high=90, size=1000)

# Plot
plt.figure(figsize=(6, 5))
plt.hist(uniform_data, bins=30)
plt.title("Uniform Distribution")
plt.show()
