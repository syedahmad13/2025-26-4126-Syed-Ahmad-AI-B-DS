# %% [markdown]
# <a href="https://colab.research.google.com/github/syedahmad13/2025-26-4126-Syed-Ahmad-AI-B-DS/blob/main/Week_4_24.02.2026/outliers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Interquantile Range(IQR)
import pandas as pd
data={
    'Name':['A','B','C','D','E','F'],
    'Age':[13,24,25,29,120,23]
}
df=pd.DataFrame(data)
print("Original DataFrame:")
print(df)
Q1=df['Age'].quantile(0.25)
Q3=df['Age'].quantile(0.75)
IQR=Q3-Q1
print("\nInterquantile Range(IQR):",IQR)
lower_bound=Q1-1.5*IQR
upper_bound=Q3+1.5*IQR
print("\nLower Bound:",lower_bound)
print("\nUpper Bound:",upper_bound)
outliers=df[(df['Age']<lower_bound)|(df['Age']>upper_bound)]
print("\nOutliers using IQR method:")
print(outliers)
# Out:
# Original DataFrame:
#   Name  Age
# 0    A   13
# 1    B   24
# 2    C   25
# 3    D   29
# 4    E  120
# 5    F   23
#
# Interquantile Range(IQR): 4.75
#
# Lower Bound: 16.125
#
# Upper Bound: 35.125
#
# Outliers using IQR method:
#   Name  Age
# 0    A   13
# 4    E  120
