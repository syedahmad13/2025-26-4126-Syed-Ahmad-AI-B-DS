# %% [markdown]
# <a href="https://colab.research.google.com/github/syedahmad13/2025-26-4126-Syed-Ahmad-AI-B-DS/blob/main/Week%205/Hypothesis_Testing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#hypothesis testing

import math
n=100
x=60
p_hat=x/n
SE=math.sqrt(p_hat*(1-p_hat)/n)
#Confidence interval
z=1.96
lower=p_hat-z*SE
upper=p_hat+z*SE
print("Sample proportion:",p_hat)
print("Confidence Interval=",(lower,upper))
po=0.50
z_test=(p_hat-po)/math.sqrt(po*(1-po)/n)
print("Z-value:",z_test)
if abs(z_test)>1.96:
  print("Reject Ho")
else:
  print("Do not reject Ho")
# Out:
# Sample proportion: 0.6
# Confidence Interval= (0.5039800020828994, 0.6960199979171006)
# Z-value: 1.9999999999999996
# Reject Ho
